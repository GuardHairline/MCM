# %% [markdown]
# # MCM项目超参数搜索 - Kaggle运行
#
# 本Notebook用于在Kaggle上运行MCM项目的MATE、MNER、MABSA超参数搜索实验。
#
# ## 设置要求
#
# 1. **加速器**: GPU P100 或 T4
# 2. **数据集**: 添加你上传的MCM项目数据集
# 3. **网络**: 开启（如果需要下载额外依赖）
#
# ## 预计运行时间
#
# - 每个实验: 1.5-2小时
# - 本Notebook配置运行: 3-5个实验（约6-10小时）
